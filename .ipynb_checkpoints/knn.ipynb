# %%
import pandas as pd 
fileName = '/content/FinalData.csv'
df2 = pd.read_csv(fileName)

# %%
df2
# Out:
#     Unnamed: 0        Name                                     Address Chain  \
# 0            0     Million  0x6B4c7A5e3f0B99FCD83e9c089BDDD6c7FCe5c611   ETH
# 1            1   ThorChain  0x3155BA85D5F96b2d030a4966AF206230e46849cb   ETH
# 2            2       Titan  0x3A8cCCB969a61532d1E6005e2CE12C200caeCe87   ETH
# 3            3       Squid  0x21ad647b8F4Fe333212e735bfC1F36B4941E6Ad2   ETH
# 4            4  BitConnect  0x88e304D8638c31DaC3336917bbE4A152927198D8   ETH
# 5            5     Uniswap  0x1f9840a85d5aF5bf1D1762F925BDADdC4201F984   ETH
# 6            6   SushiSwap  0x6B3595068778DD592e39A122f4f5a5cF09C90fE2   ETH
# 7            7        Aave  0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9   ETH
# 8            8         DAI  0x6b175474e89094c44da98b954eedeac495271d0f   ETH
# 9            9     Polygon  0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0   ETH
# 10          10      Cosmos  0x8D983cb9388EaC77af0474fA441C4815500Cb7BB   ETH
# ...

# %%
df2.describe()
# Out:
#        Unnamed: 0  AllTimeHigh    AllTimeLow       scam  TopHolding  \
# count     14.0000    14.000000  1.400000e+01  14.000000   14.000000
# mean       6.5000   382.819286  6.401579e+00   0.357143   80.441429
# std        4.1833   768.839949  1.613498e+01   0.497245   18.444213
# min        0.0000     2.920000  4.000000e-12   0.000000   31.020000
# 25%        3.2500    18.890000  2.272750e-01   0.000000   75.437500
# 50%        6.5000    44.835000  4.463500e-01   0.000000   81.000000
# 75%        9.7500   404.500000  1.083875e+00   1.000000   94.970000
# max       13.0000  2861.000000  5.700000e+01   1.000000  100.000000
#
#        ContractRatio
# count      14.000000
# mean        0.223970
# std         0.254915
# min         0.000000
# 25%         0.005563
# 50%         0.137487
# 75%         0.396755
# max         0.781520

# %%
df2.corr()
# Out:
#                Unnamed: 0  AllTimeHigh  AllTimeLow      scam  TopHolding  \
# Unnamed: 0       1.000000    -0.167039    0.195834 -0.832050    0.219899
# AllTimeHigh     -0.167039     1.000000    0.175435  0.335730    0.301006
# AllTimeLow       0.195834     0.175435    1.000000 -0.283938   -0.047645
# scam            -0.832050     0.335730   -0.283938  1.000000   -0.001989
# TopHolding       0.219899     0.301006   -0.047645 -0.001989    1.000000
# ContractRatio   -0.045256     0.647639    0.025937  0.121382    0.136762
#
#                ContractRatio
# Unnamed: 0         -0.045256
# AllTimeHigh         0.647639
# AllTimeLow          0.025937
# scam                0.121382
# TopHolding          0.136762
# ContractRatio       1.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     14 non-null     int64
#  1   Name           14 non-null     object
#  2   Address        14 non-null     object
#  3   Chain          14 non-null     object
#  4   AllTimeHigh    14 non-null     float64
#  5   AllTimeLow     14 non-null     float64
#  6   scam           14 non-null     int64
#  7   TopHolding     14 non-null     float64
#  8   ContractRatio  14 non-null     float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.1+ KB

# %%
df=df2

# %%
df
# Out:
#     Unnamed: 0        Name                                     Address Chain  \
# 0            0     Million  0x6B4c7A5e3f0B99FCD83e9c089BDDD6c7FCe5c611   ETH
# 1            1   ThorChain  0x3155BA85D5F96b2d030a4966AF206230e46849cb   ETH
# 2            2       Titan  0x3A8cCCB969a61532d1E6005e2CE12C200caeCe87   ETH
# 3            3       Squid  0x21ad647b8F4Fe333212e735bfC1F36B4941E6Ad2   ETH
# 4            4  BitConnect  0x88e304D8638c31DaC3336917bbE4A152927198D8   ETH
# 5            5     Uniswap  0x1f9840a85d5aF5bf1D1762F925BDADdC4201F984   ETH
# 6            6   SushiSwap  0x6B3595068778DD592e39A122f4f5a5cF09C90fE2   ETH
# 7            7        Aave  0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9   ETH
# 8            8         DAI  0x6b175474e89094c44da98b954eedeac495271d0f   ETH
# 9            9     Polygon  0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0   ETH
# 10          10      Cosmos  0x8D983cb9388EaC77af0474fA441C4815500Cb7BB   ETH
# ...

# %%
col=['Name','Address','Chain','AllTimeHigh','AllTimeLow']
df.drop(col,axis=1,inplace=True)

# %%
#function which return return of min-max eq
def norm(item):
	return (item - item.min())/(item.max() - item.min())
#apply norm function to each item in dataframe
df = df.apply(norm)
df
# Out:
#     Unnamed: 0  scam  TopHolding  ContractRatio
# 0     0.000000   1.0    0.603943       0.659145
# 1     0.076923   1.0    0.000000       0.029700
# 2     0.153846   1.0    1.000000       0.000000
# 3     0.230769   1.0    0.974920       1.000000
# 4     0.307692   1.0    1.000000       0.000000
# 5     0.384615   0.0    0.633807       0.009245
# 6     0.461538   0.0    0.674253       0.098859
# 7     0.538462   0.0    0.704407       0.252986
# 8     0.615385   0.0    0.427225       0.301010
# 9     0.692308   0.0    0.744709       0.664239
# 10    0.769231   0.0    0.941577       0.000000
# 11    0.846154   0.0    0.883589       0.520059
# 12    0.923077   0.0    0.676283       0.470505
# 13    1.000000   0.0    0.765729       0.006410

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     14 non-null     float64
#  1   scam           14 non-null     float64
#  2   TopHolding     14 non-null     float64
#  3   ContractRatio  14 non-null     float64
# dtypes: float64(4)
# memory usage: 576.0 bytes

# %%
#Extracting Independent and dependent Variable  
x= df.iloc[:, [2,3]].values  
y= df.iloc[:, 1].values  
  
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)  
  
#feature Scaling  
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
k_range = range(1, 11)

# We can create Python dictionary using [] or dict()
scores = []

# We use a loop through the range 1 to 26
# We append the scores in the dictionary
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

print(scores)
# Out:
# [1.0, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75]

# %%
df.shape
# Out:
# (14, 4)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)

# %%
#Fitting K-NN classifier to the training set  
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Predicting the test set result  
y_pred= classifier.predict(x_test)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[3, 0],
#        [1, 0]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     14 non-null     float64
#  1   scam           14 non-null     float64
#  2   TopHolding     14 non-null     float64
#  3   ContractRatio  14 non-null     float64
# dtypes: float64(4)
# memory usage: 576.0 bytes

# %%
#importing library
import matplotlib.pyplot as plt
#datasets
alltimehigh = df['ContractRatio']
alltimelow = df['TopHolding']
#scatter plot for the dataset
plt.scatter(alltimehigh, alltimelow)
plt.show()

# %%
num=float(input())
num2=float(input())
# Out:
# 100
# 0

# %%
import numpy as nm
features = nm.array([[num,num2]])
# using inputs to predict the output
prediction = knn.predict(features)
print("Prediction: {}".format(prediction))
# Out:
# Prediction: [0.]
